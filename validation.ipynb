# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load Model
model = tf.keras.models.load_model("keras-YOLOv3-model-set//weights//yolov4_reorder_output.h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SEKIGA~1\AppData\Local\Temp/ipykernel_11032/1340444290.py in <module>
#       1 # Load Model
# ----> 2 model = tf.keras.models.load_model("keras-YOLOv3-model-set//weights//yolov4_reorder_output.h5")
#
# ~\Anaconda3\envs\sekigahara\lib\site-packages\tensorflow\python\keras\saving\save.py in load_model(filepath, custom_objects, compile, options)
#     180     if (h5py is not None and (
#     181         isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
# --> 182       return hdf5_format.load_model_from_hdf5(filepath, custom_objects, compile)
#     183
#     184     filepath = path_to_string(filepath)
#
# ~\Anaconda3\envs\sekigahara\lib\site-packages\tensorflow\python\keras\saving\hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
# ...
